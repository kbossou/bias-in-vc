# %%
# import different libraries
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('companies-5-12-2019.csv')
data.head()
# Out:
#   Organization Name                              Organization Name URL  \
# 0         Techstars  https://www.crunchbase.com/organization/techstars
# 1         Instagram  https://www.crunchbase.com/organization/instagram
# 2       Beyond Meat  https://www.crunchbase.com/organization/beyond...
# 3            Xiaomi     https://www.crunchbase.com/organization/xiaomi
# 4              Uber       https://www.crunchbase.com/organization/uber
#
#                                           Categories  \
# 0       Finance, Financial Services, Venture Capital
# 1   Mobile, Photo Sharing, Photography, Social Media
# 2    Food and Beverage, Food Processing, Health Care
# 3             Consumer Electronics, Internet, Mobile
# 4  Customer Service, Mobile Apps, Public Transpor...
#
#                         Headquarters Location  \
# 0            Boulder, Colorado, United States
# 1       Menlo Park, California, United States
# 2  Manhattan Beach, California, United States
# 3                     Beijing, Beijing, China
# 4    San Francisco, California, United States
#
#                                          Description CB Rank (Company)  \
# 0  Techstars is the worldwide network that helps ...                 1
# 1  Instagram is a free photo sharing application ...                 2
# 2     Beyond Meat is planting The Future of Protein.                 3
# 3  Xiaomi is an electronics and software company ...                 4
# 4  Uber develops, markets, and operates a ride-sh...                 5
#
#                                 Headquarters Regions Estimated Revenue Range  \
# 0                    Greater Denver Area, Western US             $1M to $10M
# 1  San Francisco Bay Area, Silicon Valley, West C...                     NaN
# 2   Greater Los Angeles Area, West Coast, Western US            $10M to $50M
# 3                                Asia-Pacific (APAC)                     NaN
# 4     San Francisco Bay Area, West Coast, Western US                   $10B+
#
#   Operating Status Founded Date  ... Apptopia - Number of Apps  \
# 0           Active   2006-10-01  ...                       NaN
# 1           Active   2010-10-06  ...                        10
# 2           Active   2009-01-01  ...                       NaN
# 3           Active   2010-04-04  ...                        29
# 4           Active   2009-03-01  ...                        14
#
#   Apptopia - Downloads Last 30 Days Siftery - Total Products Active  \
# 0                               NaN                           141.0
# 1                        48,751,504                            46.0
# 2                               NaN                            21.0
# 3                         3,037,404                            14.0
# 4                        25,898,296                           208.0
#
#   IPqwery - Patents Granted IPqwery - Trademarks Registered  \
# 0                       NaN                             NaN
# 1                         0                              48
# 2                       NaN                             NaN
# 3                     1,128                              16
# 4                       531                              25
#
#   IPqwery - Most Popular Patent Class  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3    Electric Communication Technique
# 4              Computing; Calculating
#
#               IPqwery - Most Popular Trademark Class Aberdeen - IT Spend  \
# 0                                                NaN            169113.0
# 1  Scientific and electric apparatus and instruments                 NaN
# 2                                                NaN            265927.0
# 3  Scientific and electric apparatus and instruments                 NaN
# 4  Scientific and electric apparatus and instruments                 NaN
#
#   Aberdeen - IT Spend Currency  Aberdeen - IT Spend Currency (in USD)
# 0                          USD                               169113.0
# 1                          NaN                                    NaN
# 2                          USD                               265927.0
# 3                          NaN                                    NaN
# 4                          NaN                                    NaN
#
# [5 rows x 60 columns]

# %%
data2 = pd.read_csv('founders_cb.csv')
data2.head()
# Out:
# /Users/benjamin/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0        Full Name  \
# 0           0  Jason Calacanis
# 1           1     LeBron James
# 2           2     Marc Benioff
# 3           3  Serena Williams
# 4           4       Jeff Kearl
#
#                                        Full Name URL   Primary Job Title  \
# 0  https://www.crunchbase.com/person/jason-calacanis       Founder & CEO
# 1     https://www.crunchbase.com/person/lebron-james          Co-Founder
# 2     https://www.crunchbase.com/person/marc-benioff    Founder & Co-CEO
# 3  https://www.crunchbase.com/person/serena-williams             Founder
# 4       https://www.crunchbase.com/person/jeff-kearl  Co-Founder and CEO
#
#          Primary Organization  \
# 0                  Inside.com
# 1                  PureBrands
# 2                  Salesforce
# 3  Serena Williams Foundation
# 4                      Stance
#
#                             Primary Organization URL  \
# 0  https://www.crunchbase.com/organization/inside...
# 1  https://www.crunchbase.com/organization/purebr...
# 2  https://www.crunchbase.com/organization/salesf...
# 3  https://www.crunchbase.com/organization/serena...
# 4     https://www.crunchbase.com/organization/stance
#
#                                      Location CB Rank (Person) First Name  \
# 0    San Francisco, California, United States                2      Jason
# 1              Cleveland, Ohio, United States                4     LeBron
# 2    San Francisco, California, United States                7       Marc
# 3  Palm Beach Gardens, Florida, United States                8     Serena
# 4     San Clemente, California, United States               13       Jeff
#
#    Last Name  ... Number of Portfolio Companies Number of Investments  \
# 0  Calacanis  ...                          61.0                  70.0
# 1      James  ...                           2.0                   3.0
# 2    Benioff  ...                          92.0                 125.0
# 3   Williams  ...                           1.0                   1.0
# 4      Kearl  ...                          24.0                  27.0
#
#   Number of Partner Investments Number of Lead Investments Number of Exits  \
# 0                         122.0                        5.0            18.0
# 1                           NaN                        NaN             1.0
# 2                           NaN                        8.0            24.0
# 3                          22.0                        NaN             NaN
# 4                           4.0                        NaN            10.0
#
#   Number of Exits (IPO) Number of Events  Trend Score (7 Days)  \
# 0                  18.0              8.0                  -0.6
# 1                   1.0              NaN                  -1.0
# 2                  24.0             20.0                  -0.4
# 3                   NaN              1.0                  -0.4
# 4                  10.0              1.0                   0.6
#
#    Trend Score (30 Days)  Trend Score (90 Days)
# 0                    4.5                    9.8
# 1                   -0.7                   -0.5
# 2                   -0.4                   -0.1
# 3                    3.2                    0.7
# 4                    9.9                    9.9
#
# [5 rows x 28 columns]

# %%
new_df = pd.merge(data, data2,  how='left', left_on=['Organization Name'], right_on = ['Primary Organization'])

# %%
gender = new_df['Gender'].notnull()
new_df = new_df[gender]
new_df = new_df.drop_duplicates(subset=['Organization Name'])
new_df
# Out:
#                  Organization Name  \
# 0                        Techstars
# 4                        Instagram
# 6                           Xiaomi
# 14                      Epic Games
# 15                Tencent Holdings
# 17                        SoftBank
# 19                Impossible Foods
# 21                   Alibaba Group
# 23               Rivian Automotive
# 24                             Ola
# 27                          NVIDIA
# 30                          Cruise
# 32                         Netflix
# 36                          Square
# 37                        Coursera
# 41                      Sumo Logic
# 42                       ByteDance
# 43                         Harry's
# 46                         Twitter
# 47                         23andMe
# 49                        Facebook
# 50                          Seedrs
# 52                      Vice Media
# 54                         MongoDB
# 59                          Tinder
# 62                          Airbnb
# 66                 Rent the Runway
# 67             Samsung Electronics
# 68                   Delivery Hero
# 70                       Robinhood
# ...                            ...
# 15     Tencent is a internet service portal offering ...                 7
# 17     SoftBank provides fixed line, mobile telephony...                 8
# 19     Impossible Foods develops a new generation of ...                10
# 21     Alibaba Group enables businesses to transform ...                11
# 23     Rivian Automotive is an automotive technology ...                12
# 24     Ola operates a mobile technology platform that...                13
# 27     NVIDIA manufactures integrated circuits for us...                15
# 30     Cruise is building the world’s most advanced s...                17
# 32     Netflix is an online platform that enables use...                19
# 36     Square is a merchant services aggregator and m...                23
# 37     Coursera is an online education company that s...                24
# 41     Sumo Logic, a log management and analytics ser...                28
# 42     ByteDance is an internet technology company th...                29
# 43     Harry's allows users to buy razors, German eng...                30
# 46     Twitter is a social networking platform that a...                32
# 47     23andMe is a human genome research company tha...                33
# 49     Facebook is an online social networking servic...                35
# 50     Seedrs is a UK-based equity crowdfunding platf...                36
# 52     Vice Media is a North American digital media a...                37
# 54     MongoDB is a next-generation database that hel...                38
# 59     Tinder anonymously finds people nearby that li...                42
# 62     Airbnb is an online community marketplace for ...                45
# 66     Rent the Runway is an online e-commerce websit...                47
# 67     Samsung Electronics is a South Korean multinat...                48
# 68     Delivery Hero is a network of online food orde...                49
# 70     Robinhood is a stock brokerage that allows cus...                50
# ...                                                  ...               ...
# 36171  Delivering on the promise of self-driving cars...            29,849
# 36177  Alt12 Apps is a developer of mobile applicatio...            29,855
# 36183  Reel is a platform for debt-free shopping. A s...            29,861
# 36198  The Tasteful app helps you Discover Delicious ...            29,872
# 36199  A smart digital-money account that helps you d...            29,873
# 36201              The largest data platform of Startups            29,874
# 36204                 Digital Health Insurance ecosystem            29,877
# 36213  The PlotBox mapping module is leading the way,...            29,887
# 36214  Adagio Medical is engaged in the research and ...            29,888
# 36215  Intellectus is an exclusive, private MFO for E...            29,889
# 36237  Prodigy Game has created a free, Pokémon-style...            29,909
# 36239  Fetch is a flexible delivery service that conn...            29,909
# 36246  SaaS platform which enables measurement based ...            29,917
# 36249  Greenwood Hall (OTCBB:ELRN) helps colleges and...            29,920
# 36251  GONG is a playful social news platform where s...            29,922
# 36253  Feedvisor is an algorithmic pricing and revenu...            29,924
# 36255  Ento provide end-to-end staff management softw...            29,924
# 36272  Bitspark is a blockchain company that provides...            29,943
# 36275        Taking the stress out of storage since 2013            29,945
# 36282  Cedar Capital delivers innovative investment s...            29,953
# 36285  Junar offers a cloud-based open data platform ...            29,956
# 36288  Leo offers a disappearing messaging app and ul...            29,957
# 36292  Based in New York and Shanghai, Bomoda makes C...            29,958
# 36293  Millennium Entertainment - Theatrical Film/Mov...            29,959
# 36296  SmartyPans makes sensor enabled cookware to ma...            29,961
# 36300  GroupSense is a provider of cyber intelligence...            29,968
# 36303                                               SaaS            29,972
# 36317  influencer search engine and marketplace,  Rob...            29,984
# 36320  Reliance Capital Management an integrated fina...            29,985
# 36348  Mobile recruiting solutions that help hiring o...            30,014
#
#                                     Headquarters Regions  \
# 0                        Greater Denver Area, Western US
# 4      San Francisco Bay Area, Silicon Valley, West C...
# 17                        NaN           Active   1981-09-03  ...
# 19              $50M to $100M           Active   2011-01-01  ...
# 21                        NaN           Active   1999-04-04  ...
# 23               $10M to $50M           Active   2009-01-01  ...
# 24             $100M to $500M           Active   2010-12-03  ...
# 27                        NaN           Active   1993-01-01  ...
# 30                        NaN           Active   2013-01-01  ...
# 32                        NaN           Active   1997-01-01  ...
# 36                        NaN           Active   2009-02-01  ...
# 37                        NaN           Active   2012-01-01  ...
# 41              $50M to $100M           Active   2010-01-01  ...
# 42                        NaN           Active   2012-03-01  ...
# 43               $10M to $50M           Active   2013-10-01  ...
# 46                        NaN           Active   2006-03-21  ...
# 47             $100M to $500M           Active   2006-04-01  ...
# 49                        NaN           Active   2004-02-04  ...
# 50                $1M to $10M           Active   2009-03-16  ...
# 52                        NaN           Active   1994-01-01  ...
# 54                        NaN           Active   2007-11-01  ...
# 59                $1M to $10M           Active   2012-09-01  ...
# 62             $100M to $500M           Active   2008-08-11  ...
# 66             $100M to $500M           Active   2009-11-09  ...
# 67                        NaN           Active   1969-02-12  ...
# 68                        NaN           Active   2011-05-01  ...
# 70                        NaN           Active   2013-01-01  ...
# ...                       ...              ...          ...  ...
# 36171             $1M to $10M           Active   2017-02-01  ...
# 36177                     NaN           Active   2009-09-01  ...
# 36183                     NaN           Active   2016-01-01  ...
# 36198           Less than $1M           Active   2010-01-01  ...
# 36199                     NaN           Active   2015-01-01  ...
# 36201             $1M to $10M           Active   2013-06-01  ...
# 36204             $1M to $10M           Active   2015-08-01  ...
# 36213                     NaN           Active   2011-01-01  ...
# 36214           Less than $1M           Active   2011-01-01  ...
# 36215           Less than $1M           Active   2015-07-01  ...
# 36237             $1M to $10M           Active   2011-06-01  ...
# 36239             $1M to $10M           Active   2018-04-27  ...
# 36246             $1M to $10M           Active   2011-01-01  ...
# 36249                     NaN           Active   1998-02-01  ...
# 36251             $1M to $10M           Active          NaN  ...
# 36253             $1M to $10M           Active   2011-03-01  ...
# 36255             $1M to $10M           Active   2009-01-01  ...
# 36272                     NaN           Active   2014-04-01  ...
# 36275           Less than $1M           Active   2014-01-01  ...
# 36282             $1M to $10M           Active   2008-01-01  ...
# 36285             $1M to $10M           Active   2010-01-01  ...
# 36288                     NaN           Active   2013-09-01  ...
# 36292                     NaN           Active   2012-01-01  ...
# 36293                     NaN           Active   2010-01-01  ...
# 36296           Less than $1M           Active   2015-06-14  ...
# 36300             $1M to $10M           Active   2014-06-01  ...
# 36303                     NaN           Active   2017-01-01  ...
# 36317             $1M to $10M           Active   2014-01-01  ...
# 36320                     NaN           Active          NaN  ...
# 36348             $1M to $10M           Active   2012-01-01  ...
#
#       Number of Portfolio Companies Number of Investments  \
# 0                               3.0                   3.0
# 4                               4.0                   4.0
# 6                               5.0                   6.0
# 14                              NaN                   NaN
# 15                              1.0                   1.0
# 17                              NaN                   NaN
# 19                              NaN                   NaN
# 21                              1.0                   1.0
# 23                              NaN                   NaN
# 24                              5.0                   7.0
# 27                              NaN                   NaN
# 30                             14.0                  16.0
# 32                              2.0                   3.0
# 36                             16.0                  20.0
# 37                              NaN                   NaN
# 41                              NaN                   NaN
# 42                              NaN                   NaN
# 43                              2.0                   2.0
# 46                             14.0                  15.0
# 47                              9.0                  10.0
# 49                              7.0                   8.0
# 50                              NaN                   NaN
# 52                              1.0                   1.0
# 54                             12.0                  16.0
# 59                              1.0                   1.0
# 62                              4.0                   5.0
# 66                              6.0                   6.0
# 67                              NaN                   NaN
# 68                              5.0                   7.0
# 70                              NaN                   NaN
# ...                             ...                   ...
# 36171                           NaN                   NaN
# 36177                           NaN                   NaN
# 36183                           NaN                   NaN
# 36198                           NaN                   NaN
# 36199                           NaN                   NaN
# 36201                           6.0                   6.0
# 36204                           NaN                   NaN
# 36213                           NaN                   NaN
# 36214                           NaN                   NaN
# 36215                          14.0                  17.0
# 36237                           NaN                   NaN
# 36239                           NaN                   NaN
# 36246                           NaN                   NaN
# 36249                           NaN                   NaN
# 36251                           NaN                   NaN
# 36253                           NaN                   NaN
# 36255                           NaN                   NaN
# 36272                           NaN                   NaN
# 36275                           NaN                   NaN
# 36282                           NaN                   NaN
# 36285                           NaN                   NaN
# 36288                           NaN                   NaN
# 36292                           NaN                   NaN
# 36293                           NaN                   NaN
# 36296                           NaN                   NaN
# 36300                           NaN                   NaN
# 36303                           NaN                   NaN
# 36317                           NaN                   NaN
# 36320                           NaN                   NaN
# 36348                           NaN                   NaN
#
#       Number of Partner Investments Number of Lead Investments  \
# 0                               NaN                        NaN
# 4                               NaN                        NaN
# 6                               1.0                        2.0
# 14                              NaN                        NaN
# 15                              NaN                        NaN
# 17                              7.0                        NaN
# 19                              NaN                        NaN
# 21                              NaN                        NaN
# 23                              NaN                        NaN
# 24                              NaN                        2.0
# 27                              NaN                        NaN
# 30                              NaN                        NaN
# 32                              NaN                        3.0
# 36                              1.0                        NaN
# 37                              NaN                        NaN
# 41                              NaN                        NaN
# 42                              NaN                        NaN
# 43                              NaN                        NaN
# 46                              NaN                        1.0
# 47                              NaN                        NaN
# 49                              NaN                        1.0
# 50                              NaN                        NaN
# 52                              NaN                        NaN
# 54                              NaN                        3.0
# 59                              NaN                        NaN
# 62                              NaN                        NaN
# 66                              NaN                        NaN
# 67                              NaN                        NaN
# 68                              NaN                        NaN
# 70                              NaN                        NaN
# ...                             ...                        ...
# 36171                           NaN                        NaN
# 36177                           NaN                        NaN
# 36183                           NaN                        NaN
# 36198                           NaN                        NaN
# 36199                           NaN                        NaN
# 36201                           1.0                        NaN
# 36204                           NaN                        NaN
# 36213                           NaN                        NaN
# 36214                           2.0                        NaN
# 36215                           NaN                        NaN
# 36237                           NaN                        NaN
# 36239                           NaN                        NaN
# 36246                           NaN                        NaN
# 36249                           NaN                        NaN
# 36251                           NaN                        NaN
# 36253                           NaN                        NaN
# 36255                           NaN                        NaN
# 36272                           NaN                        NaN
# 36275                           NaN                        NaN
# 36282                           NaN                        NaN
# 36285                           NaN                        NaN
# 36288                           NaN                        NaN
# 36292                           NaN                        NaN
# 36293                           NaN                        NaN
# 36296                           NaN                        NaN
# 36300                           NaN                        NaN
# 36303                           NaN                        NaN
# 36317                           NaN                        NaN
# 36320                           NaN                        NaN
# 36348                           NaN                        NaN
#
#       Number of Exits Number of Exits (IPO) Number of Events_y  \
# 0                 2.0                   2.0                NaN
# 4                 NaN                   NaN                6.0
# 6                 NaN                   NaN                NaN
# 14                NaN                   NaN                3.0
# 15                NaN                   NaN                1.0
# 17                NaN                   NaN                NaN
# 19                NaN                   NaN                3.0
# 21                NaN                   NaN                NaN
# 23                NaN                   NaN                1.0
# 24                NaN                   NaN                3.0
# 27                NaN                   NaN                8.0
# 30                2.0                   2.0                3.0
# 32                1.0                   1.0                8.0
# 36                4.0                   4.0                6.0
# 37                NaN                   NaN               15.0
# 41                NaN                   NaN                7.0
# 42                NaN                   NaN                NaN
# 43                1.0                   1.0                2.0
# 46                5.0                   5.0                1.0
# 47                NaN                   NaN                9.0
# 49                NaN                   NaN                6.0
# 50                NaN                   NaN                4.0
# 52                NaN                   NaN                5.0
# 54                1.0                   1.0                2.0
# 59                NaN                   NaN                2.0
# 62                3.0                   3.0                6.0
# 66                1.0                   1.0                8.0
# 67                NaN                   NaN                NaN
# 68                NaN                   NaN               10.0
# 70                NaN                   NaN                6.0
# ...               ...                   ...                ...
# 36171             NaN                   NaN                2.0
# 36177             NaN                   NaN                NaN
# 36183             NaN                   NaN                NaN
# 36198             NaN                   NaN                NaN
# 36199             NaN                   NaN                NaN
# 36201             NaN                   NaN                NaN
# 36204             NaN                   NaN                NaN
# 36213             NaN                   NaN                NaN
# 36214             NaN                   NaN                NaN
# 36215             5.0                   5.0                NaN
# 36237             NaN                   NaN                NaN
# 36239             NaN                   NaN                NaN
# 36246             NaN                   NaN                NaN
# 36249             NaN                   NaN                2.0
# 36251             NaN                   NaN                NaN
# 36253             NaN                   NaN                NaN
# 36255             NaN                   NaN                NaN
# 36272             NaN                   NaN                1.0
# 36275             NaN                   NaN                NaN
# 36282             NaN                   NaN                NaN
# 36285             NaN                   NaN                NaN
# 36288             NaN                   NaN                1.0
# 36292             NaN                   NaN                NaN
# 36293             NaN                   NaN                NaN
# 36296             NaN                   NaN                1.0
# 36300             NaN                   NaN                NaN
# 36303             NaN                   NaN                NaN
# 36317             NaN                   NaN                NaN
# 36320             NaN                   NaN                NaN
# 36348             NaN                   NaN                NaN
#
#       Trend Score (7 Days) Trend Score (30 Days)  Trend Score (90 Days)
# 0                     -1.4                  -1.4                    3.5
# 4                     -1.5                  -1.3                   -1.5
# 6                     -0.5                  -1.3                   -2.2
# 14                     1.2                  -1.3                    6.6
# 15                    -0.8                  -0.9                    1.8
# 17                    -0.7                  -0.5                   -0.7
# 19                    -0.3                  -0.7                    6.1
# 21                    -0.4                  -0.2                   -0.4
# 23                    -0.7                  -1.2                   -0.8
# 24                     0.4                  -0.1                   -1.1
# 27                    -0.2                  -0.6                   -6.0
# 30                    -0.7                   0.8                   -0.7
# 32                    -1.8                  -3.2                   -0.2
# 36                    -0.2                  -0.9                   -0.5
# 37                     1.0                  -0.3                   -2.0
# 41                    -0.9                  -1.0                    8.6
# 42                    -0.3                  -0.5                   -0.4
# 43                    -1.3                  -1.7                    7.5
# 46                    -1.1                   6.3                    8.0
# 47                    -0.4                  -0.6                   -2.9
# 49                    -1.2                  -1.5                   -0.1
# 50                    -0.9                  -0.5                    1.1
# 52                    -1.4                  -1.5                    8.0
# 54                     0.7                  -0.8                   -2.7
# 59                    -0.3                  -0.6                   -0.8
# 62                    -0.1                  -1.2                   -0.6
# 66                    -1.0                  -1.6                    1.8
# 67                     0.2                   0.1                   -0.9
# 68                    -1.3                  -2.2                   -1.6
# 70                    -0.4                   3.6                    2.6
# ...                    ...                   ...                    ...
# 36171                  0.2                  -1.2                   -2.9
# 36177                 -0.3                  -1.3                   -0.1
# 36183                  5.3                   6.0                    4.1
# 36198                 -0.9                   0.3                   -0.8
# 36199                 -0.2                   0.0                    3.7
# 36201                 -0.2                   0.3                   -0.3
# 36204                 -0.6                   2.6                    6.2
# 36213                  1.1                   6.8                    7.6
# 36214                 -0.5                   1.0                   -0.2
# 36215                 -1.1                   8.1                    7.8
# 36237                  1.0                  -0.1                   -0.2
# 36239                  0.5                  -0.4                    3.4
# 36246                 -0.4                  -0.1                    5.3
# 36249                 -1.2                   4.4                    9.4
# 36251                  2.2                  -0.3                    4.4
# 36253                  0.5                   3.6                    5.6
# 36255                  4.5                   8.0                    9.0
# 36272                 -0.2                  -0.3                   -1.4
# 36275                  0.3                   7.0                    3.9
# 36282                 -0.2                  -0.6                   -0.1
# 36285                  2.4                   5.5                   -0.7
# 36288                  0.1                  -0.4                    1.5
# 36292                 -0.3                  -0.1                   -0.7
# 36293                 -0.5                  -0.4                    1.4
# 36296                 -1.2                  -1.1                   -1.2
# 36300                 -1.3                  -1.9                   -1.8
# 36303                 -1.3                  -0.3                    3.3
# 36317                  1.0                   1.3                    2.8
# 36320                 -1.0                  -0.8                   -1.0
# 36348                  0.2                   0.7                    1.4
#
# [12442 rows x 88 columns]

# %%
null = new_df['Categories'].notnull()
new_df = new_df[null]
new_df.shape
# Out:
# (12438, 88)

# %%
null = new_df['Headquarters Regions'].notnull()
new_df = new_df[null]
new_df.shape
# Out:
# (11644, 88)

# %%
categories_counts= new_df['Gender'].value_counts()
plt.figure(figsize=(6,2))
rg = sns.barplot(y=categories_counts.index, x=categories_counts.values)
plt.setp(rg.get_xticklabels(), rotation=90)
print(categories_counts)
# Out:
# Male                 10396
# Female                1247
# Transgender Woman        1
# Name: Gender, dtype: int64

# %%
#simplifying categories
new_df.loc[new_df['Categories'].str.contains('Finance|FinTech|Financial|Banking', case=False), 'Categories'] = 'Finance'
new_df.loc[new_df['Categories'].str.contains('Biotechnology', case=False), 'Categories'] = 'Biotechnology'
new_df.loc[new_df['Categories'].str.contains('Health Care', case=False), 'Categories'] = 'Health Care'
new_df.loc[new_df['Categories'].str.contains('E-Commerce', case=False), 'Categories'] = 'E-Commerce'
new_df.loc[new_df['Categories'].str.contains('Software', case=False), 'Categories'] = 'Software'
new_df.loc[new_df['Categories'].str.contains('Internet', case=False), 'Categories'] = 'Internet'
new_df.loc[new_df['Categories'].str.contains('Information Technology', case=False), 'Categories'] = 'Information Technology'
new_df.loc[new_df['Categories'].str.contains('Education', case=False), 'Categories'] = 'Education'
new_df.loc[new_df['Categories'].str.contains('Network Security|Cyber Security', case=False), 'Categories'] = 'Security'
new_df.loc[new_df['Categories'].str.contains('Real Estate', case=False), 'Categories'] = 'Real Estate'
new_df.loc[new_df['Categories'].str.contains('Tourism', case=False), 'Categories'] = 'Tourism'
new_df.loc[new_df['Categories'].str.contains('Artificial Intelligence', case=False), 'Categories'] = 'Artificial Intelligence'
new_df.loc[new_df['Categories'].str.contains('Food', case=False), 'Categories'] = 'Food'
new_df.loc[new_df['Categories'].str.contains('Advertising', case=False), 'Categories'] = 'Advertising'
new_df.loc[new_df['Categories'].str.contains('Fashion', case=False), 'Categories'] = 'Fashion'
new_df.loc[new_df['Categories'].str.contains('Data', case=False), 'Categories'] = 'Data'
new_df.loc[new_df['Categories'].str.contains('Robotics', case=False), 'Categories'] = 'Robotics'
new_df.loc[new_df['Categories'].str.contains('Gaming', case=False), 'Categories'] = 'Gaming'
new_df.loc[new_df['Categories'].str.contains('Sports', case=False), 'Categories'] = 'Sports'
new_df.loc[new_df['Categories'].str.contains('Entertainment', case=False), 'Categories'] = 'Entertainment'
new_df.loc[new_df['Categories'].str.contains('Insurance', case=False), 'Categories'] = 'Insurance'

# %%
categories_counts= new_df['Categories'].value_counts().nlargest(30)
plt.figure(figsize=(5,5))
rg = sns.barplot(y=categories_counts.index, x=categories_counts.values)
plt.setp(rg.get_xticklabels(), rotation=90)
print(categories_counts)
# Out:
# Software                                              2386
# Finance                                               1386
# E-Commerce                                            1113
# Health Care                                            966
# Internet                                               812
# Biotechnology                                          506
# Artificial Intelligence                                390
# Information Technology                                 387
# Education                                              269
# Advertising                                            248
# Data                                                   211
# Food                                                   191
# Real Estate                                            176
# Security                                               128
# Entertainment                                          108
# Gaming                                                 101
# Robotics                                                94
# Fashion                                                 81
# Sports                                                  61
# Tourism                                                 50
# Insurance                                               27
# Mobile, Telecommunications, Wireless                     5
# Human Resources, Recruiting, Staffing Agency             5
# Hospitality                                              5
# Logistics, Supply Chain Management, Transportation       4
# Health Diagnostics, Medical, Therapeutics                4
# SaaS                                                     4
# Automotive, Electric Vehicle, Transportation             4
# Apps, Mobile                                             4
# Electronics, Manufacturing, Semiconductor                3
# Name: Categories, dtype: int64

# %%
#simplifying regions
new_df.loc[new_df['Headquarters Regions'].str.contains('Asia-Pacific', case=False), 'Headquarters Regions'] = 'Asia-Pacific (APAC)'
new_df.loc[new_df['Headquarters Regions'].str.contains('European Union', case=False), 'Headquarters Regions'] = 'European Union (EU)'
new_df.loc[new_df['Headquarters Regions'].str.contains('San Francisco Bay Area', case=False), 'Headquarters Regions'] = 'San Francisco Bay Area, West Coast, Western US'

# %%
categories_counts= new_df['Headquarters Regions'].value_counts().nlargest(30)
plt.figure(figsize=(5,5))
rg = sns.barplot(y=categories_counts.index, x=categories_counts.values)
plt.setp(rg.get_xticklabels(), rotation=90)
print(categories_counts)
# Out:
# San Francisco Bay Area, West Coast, Western US                     3213
# European Union (EU)                                                1922
# Asia-Pacific (APAC)                                                1507
# Greater New York Area, East Coast, Northeastern US                 1400
# Greater Los Angeles Area, West Coast, Western US                    635
# Greater Boston Area, East Coast, New England                        531
# Greater Seattle Area, West Coast, Western US                        237
# Southern US                                                         235
# Great Lakes                                                         206
# Greater Chicago Area, Great Lakes, Midwestern US                    191
# Greater Denver Area, Western US                                     133
# Greater San Diego Area, West Coast, Western US                      121
# West Coast, Western US                                              117
# Washington DC Metro Area, East Coast, Southern US                   115
# Great Lakes, Midwestern US                                          111
# Western US                                                          101
# Greater Atlanta Area, East Coast, Southern US                        81
# East Coast, Southern US                                              79
# Greater Philadelphia Area, Great Lakes, Northeastern US              68
# Washington DC Metro Area, Southern US                                67
# Dallas/Fort Worth Metroplex, Southern US                             65
# Greater Miami Area, East Coast, Southern US                          60
# East Coast, New England, Northeastern US                             58
# Gulf Cooperation Council (GCC)                                       47
# Midwestern US                                                        45
# Research Triangle, East Coast, Southern US                           43
# Greater Phoenix Area, Western US                                     36
# Greater Minneapolis-Saint Paul Area, Great Lakes, Midwestern US      36
# Great Lakes, Northeastern US                                         35
# Greater Baltimore-Maryland Area, East Coast, Southern US             33
# Name: Headquarters Regions, dtype: int64

# %%
#creating subdatasets for the top 6 regions
data_EU = new_df[new_df['Headquarters Regions'] == 'European Union (EU)']
data_Bay = new_df[new_df['Headquarters Regions'] == 'San Francisco Bay Area, West Coast, Western US']
data_APAC = new_df[new_df['Headquarters Regions'] == 'Asia-Pacific (APAC)']
data_NY = new_df[new_df['Headquarters Regions'] == 'Greater New York Area, East Coast, Northeastern US']
data_LA = new_df[new_df['Headquarters Regions'] == 'Greater Los Angeles Area, West Coast, Western US']
data_BO = new_df[new_df['Headquarters Regions'] == 'Greater Boston Area, East Coast, New England']

# %%
print('Bay Area average funding:',data_Bay['Total Funding Amount Currency (in USD)'].sum()/len(data_Bay))
print('EU average funding:',data_EU['Total Funding Amount Currency (in USD)'].sum()/len(data_EU))
print('APAC average funding:',data_APAC['Total Funding Amount Currency (in USD)'].sum()/len(data_APAC))
print('New York average funding:',data_NY['Total Funding Amount Currency (in USD)'].sum()/len(data_NY))
print('Los Angeles average funding:',data_LA['Total Funding Amount Currency (in USD)'].sum()/len(data_LA))
print('Boston average funding:',data_BO['Total Funding Amount Currency (in USD)'].sum()/len(data_BO))
col_names =  ['Region', 'Total Funding', 'Average Funding', 'Top 10 Average Funding']
funding  = pd.DataFrame(columns = col_names)
funding.loc[0] = ['Bay', data_Bay['Total Funding Amount Currency (in USD)'].sum(), data_Bay['Total Funding Amount Currency (in USD)'].sum()/len(data_Bay), data_Bay['Total Funding Amount Currency (in USD)'].nlargest(10).sum()/10]
funding.loc[1] = ['EU', data_EU['Total Funding Amount Currency (in USD)'].sum(), data_EU['Total Funding Amount Currency (in USD)'].sum()/len(data_EU), data_EU['Total Funding Amount Currency (in USD)'].nlargest(10).sum()/10]
funding.loc[2] = ['APAC', data_APAC['Total Funding Amount Currency (in USD)'].sum(), data_APAC['Total Funding Amount Currency (in USD)'].sum()/len(data_APAC), data_APAC['Total Funding Amount Currency (in USD)'].nlargest(10).sum()/10]
funding.loc[3] = ['NY', data_NY['Total Funding Amount Currency (in USD)'].sum(), data_NY['Total Funding Amount Currency (in USD)'].sum()/len(data_NY), data_NY['Total Funding Amount Currency (in USD)'].nlargest(10).sum()/10]
funding.loc[4] = ['LA', data_LA['Total Funding Amount Currency (in USD)'].sum(), data_LA['Total Funding Amount Currency (in USD)'].sum()/len(data_LA), data_LA['Total Funding Amount Currency (in USD)'].nlargest(10).sum()/10]
funding.loc[5] = ['BO', data_BO['Total Funding Amount Currency (in USD)'].sum(), data_BO['Total Funding Amount Currency (in USD)'].sum()/len(data_BO), data_BO['Total Funding Amount Currency (in USD)'].nlargest(10).sum()/10]
funding = funding.sort_values('Total Funding', ascending=False)
funding.plot.bar(x='Region', y='Total Funding', rot=0)
funding = funding.sort_values('Average Funding', ascending=False)
funding.plot.bar(x='Region', y='Average Funding', rot=0)
funding = funding.sort_values('Top 10 Average Funding', ascending=False)
funding.plot.bar(x='Region', y='Top 10 Average Funding', rot=0)
# Out:
# Bay Area average funding: 69280810.29474013
# EU average funding: 42632453.30593132
# APAC average funding: 144334133.40544128
# New York average funding: 51108555.69571429
# Los Angeles average funding: 51574954.31968504
# Boston average funding: 54323967.11299435

# %%
Bay_10 = data_Bay.head(10).sort_values('Total Funding Amount Currency (in USD)', ascending=False)
Bay_10.plot.bar(x='Organization Name', y='Total Funding Amount Currency (in USD)', rot=0, figsize=(10,5),title = 'Bay Top 10')

EU_10 = data_EU.head(10).sort_values('Total Funding Amount Currency (in USD)', ascending=False)
EU_10.plot.bar(x='Organization Name', y='Total Funding Amount Currency (in USD)', rot=0, figsize=(10,5),title = 'EU Top 10')

APAC_10 = data_APAC.head(10).sort_values('Total Funding Amount Currency (in USD)', ascending=False)
APAC_10.plot.bar(x='Organization Name', y='Total Funding Amount Currency (in USD)', rot=0, figsize=(10,5),title = 'APAC Top 10')

NY_10 = data_NY.head(10).sort_values('Total Funding Amount Currency (in USD)', ascending=False)
NY_10.plot.bar(x='Organization Name', y='Total Funding Amount Currency (in USD)', rot=0, figsize=(10,5),title = 'NY Top 10')

LA_10 = data_LA.head(10).sort_values('Total Funding Amount Currency (in USD)', ascending=False)
LA_10.plot.bar(x='Organization Name', y='Total Funding Amount Currency (in USD)', rot=0, figsize=(10,5),title = 'LA Top 10')

BO_10 = data_BO.head(10).sort_values('Total Funding Amount Currency (in USD)', ascending=False)
BO_10.plot.bar(x='Organization Name', y='Total Funding Amount Currency (in USD)', rot=0, figsize=(10,5),title = 'BO Top 10')

# %%
categories_counts= data_Bay['Categories'].value_counts().nlargest(30)
plt.figure(figsize=(5,7))
rg = sns.barplot(y=categories_counts.index, x=categories_counts.values)
plt.setp(rg.get_xticklabels(), rotation=90)
print(categories_counts)
# Out:
# Software                                                           863
# Finance                                                            282
# Health Care                                                        266
# Internet                                                           218
# E-Commerce                                                         218
# Artificial Intelligence                                            150
# Biotechnology                                                      148
# Information Technology                                              98
# Data                                                                85
# Education                                                           63
# Advertising                                                         59
# Security                                                            49
# Robotics                                                            39
# Food                                                                38
# Gaming                                                              29
# Real Estate                                                         27
# Entertainment                                                       15
# Sports                                                              11
# Fashion                                                             10
# Tourism                                                              5
# Insurance                                                            4
# Mobile, Telecommunications, Wireless                                 3
# Communications Infrastructure, Mobile, Wireless                      2
# Wireless                                                             2
# Electronics, Manufacturing, Semiconductor                            2
# Blogging Platforms, Social Media, Social Network                     2
# Energy, Renewable Energy, Solar                                      2
# Consumer Applications, Mobile, Photo Editing                         1
# Email Marketing, Marketplace, Social Media Marketing                 1
# Automotive, Autonomous Vehicles, Leisure, Public Transportation      1
# Name: Categories, dtype: int64

# %%
categories_counts= data_EU['Categories'].value_counts().nlargest(30)
plt.figure(figsize=(5,7))
rg = sns.barplot(y=categories_counts.index, x=categories_counts.values)
plt.setp(rg.get_xticklabels(), rotation=90)
print(categories_counts)
# Out:
# Finance                                                                                                324
# Software                                                                                               301
# E-Commerce                                                                                             173
# Internet                                                                                               147
# Health Care                                                                                            124
# Artificial Intelligence                                                                                 94
# Information Technology                                                                                  72
# Biotechnology                                                                                           50
# Education                                                                                               44
# Advertising                                                                                             43
# Real Estate                                                                                             37
# Food                                                                                                    33
# Data                                                                                                    25
# Gaming                                                                                                  21
# Security                                                                                                17
# Tourism                                                                                                 15
# Sports                                                                                                  14
# Fashion                                                                                                 14
# Entertainment                                                                                           11
# Robotics                                                                                                10
# Insurance                                                                                                7
# Hospitality                                                                                              3
# Logistics, Supply Chain Management, Transportation                                                       2
# Energy, Energy Efficiency, Renewable Energy                                                              2
# Automotive, Electric Vehicle                                                                             2
# Delivery, Logistics, Supply Chain Management                                                             2
# Consumer, Consumer Applications, Pet                                                                     1
# Automotive, Broadcasting, Social                                                                         1
# Lead Generation, Market Research, Marketing, Public Relations, Reputation, Social CRM, Social Media      1
# B2B, Logistics, Marketplace, Retail, Transportation, Warehousing                                         1
# Name: Categories, dtype: int64

# %%
categories_counts= data_APAC['Categories'].value_counts().nlargest(30)
plt.figure(figsize=(5,7))
rg = sns.barplot(y=categories_counts.index, x=categories_counts.values)
plt.setp(rg.get_xticklabels(), rotation=90)
print(categories_counts)
# Out:
# Finance                                                                                    259
# E-Commerce                                                                                 250
# Software                                                                                   159
# Internet                                                                                   135
# Health Care                                                                                 92
# Information Technology                                                                      62
# Education                                                                                   47
# Artificial Intelligence                                                                     43
# Food                                                                                        34
# Real Estate                                                                                 29
# Biotechnology                                                                               24
# Data                                                                                        17
# Entertainment                                                                               16
# Advertising                                                                                 14
# Fashion                                                                                     13
# Tourism                                                                                     13
# Gaming                                                                                      12
# Robotics                                                                                     8
# Sports                                                                                       5
# Human Resources, Recruiting, Staffing Agency                                                 3
# Insurance                                                                                    3
# Automotive, Autonomous Vehicles, Electric Vehicle, Manufacturing                             3
# Automotive, Electric Vehicle, Transportation                                                 2
# Apps, Customer Service, Cycling, Last Mile Transportation, Ride Sharing, Transportation      2
# Security                                                                                     2
# Health Diagnostics, Medical, Therapeutics                                                    2
# Logistics, Railroad, Transportation                                                          2
# Agriculture, AgTech, Farming                                                                 2
# Automotive, B2B, B2C, Consumer Electronics, Recycling, Service Industry                      1
# Analytics, Broadcasting, Real Time                                                           1
# Name: Categories, dtype: int64

# %%
categories_counts= data_NY['Categories'].value_counts().nlargest(30)
plt.figure(figsize=(5,7))
rg = sns.barplot(y=categories_counts.index, x=categories_counts.values)
plt.setp(rg.get_xticklabels(), rotation=90)
print(categories_counts)
# Out:
# Software                                                                 237
# Finance                                                                  196
# E-Commerce                                                               172
# Health Care                                                              110
# Internet                                                                  97
# Advertising                                                               59
# Education                                                                 40
# Real Estate                                                               39
# Information Technology                                                    36
# Biotechnology                                                             31
# Entertainment                                                             25
# Data                                                                      23
# Artificial Intelligence                                                   22
# Fashion                                                                   21
# Food                                                                      18
# Security                                                                  13
# Sports                                                                     9
# Gaming                                                                     7
# Tourism                                                                    5
# Robotics                                                                   4
# Digital Media, News, Publishing                                            2
# Insurance                                                                  2
# Consumer Goods                                                             2
# Consumer Electronics, Mobile, Security                                     1
# College Recruiting, Corporate Training, Recruiting, Virtual Workforce      1
# News, Photography, Video                                                   1
# Apps, Natural Language Processing                                          1
# Developer Tools, Events, Recruiting, Universities                          1
# Journalism, Marketplace                                                    1
# Consumer, Home Renovation, Home Services, Interior Design                  1
# Name: Categories, dtype: int64

# %%
categories_counts= data_LA['Categories'].value_counts().nlargest(30)
plt.figure(figsize=(5,7))
rg = sns.barplot(y=categories_counts.index, x=categories_counts.values)
plt.setp(rg.get_xticklabels(), rotation=90)
print(categories_counts)
# Out:
# Software                                                       93
# E-Commerce                                                     86
# Health Care                                                    63
# Finance                                                        49
# Internet                                                       43
# Entertainment                                                  26
# Advertising                                                    26
# Biotechnology                                                  23
# Gaming                                                         21
# Food                                                           17
# Information Technology                                         16
# Artificial Intelligence                                        11
# Real Estate                                                    10
# Education                                                       8
# Data                                                            8
# Sports                                                          5
# Fashion                                                         5
# Robotics                                                        4
# Tourism                                                         3
# Security                                                        3
# Analytics, Music, Social Media, Social Network, Web Hosting     1
# B2B, Delivery, Digital Media, Enterprise                        1
# Manufacturing                                                   1
# Film Production, Video Editing, Virtual Reality                 1
# Hospital, Medical, Medical Device                               1
# Consumer Electronics, Security, Smart Home                      1
# CRM, Predictive Analytics, Sales Automation                     1
# Broadcasting, Digital Media, Music                              1
# Renewable Energy, Venture Capital                               1
# Blogging Platforms, Brand Marketing, Marketing                  1
# Name: Categories, dtype: int64

# %%
print (len(data))
print (data.columns)
# Out:
# 30000
# Index(['Organization Name', 'Organization Name URL', 'Categories',
#        'Headquarters Location', 'Description', 'CB Rank (Company)',
#        'Headquarters Regions', 'Estimated Revenue Range', 'Operating Status',
#        'Founded Date', 'Founded Date Precision', 'Exit Date',
#        'Exit Date Precision', 'Closed Date', 'Closed Date Precision',
#        'Company Type', 'Investor Type', 'Investment Stage', 'Category Groups',
#        'Number of Founders', 'Founders', 'Number of Employees',
#        'Number of Funding Rounds', 'Funding Status', 'Last Funding Date',
#        'Last Funding Amount', 'Last Funding Amount Currency',
#        'Last Funding Amount Currency (in USD)', 'Last Funding Type',
#        'Total Funding Amount', 'Total Funding Amount Currency',
#        'Total Funding Amount Currency (in USD)', 'Top 5 Investors',
#        'Number of Lead Investors', 'Number of Investors',
#        'Number of Acquisitions', 'Acquisition Status', 'IPO Status',
#        'IPO Date', 'Delisted Date', 'Delisted Date Precision',
#        'Money Raised at IPO', 'Money Raised at IPO Currency',
#        'Money Raised at IPO Currency (in USD)', 'Valuation at IPO',
#        'Valuation at IPO Currency', 'Valuation at IPO Currency (in USD)',
#        'Number of Events', 'SimilarWeb - Monthly Visits',
#        'BuiltWith - Active Tech Count', 'Apptopia - Number of Apps',
#        'Apptopia - Downloads Last 30 Days', 'Siftery - Total Products Active',
#        'IPqwery - Patents Granted', 'IPqwery - Trademarks Registered',
#        'IPqwery - Most Popular Patent Class',
#        'IPqwery - Most Popular Trademark Class', 'Aberdeen - IT Spend',
#        'Aberdeen - IT Spend Currency',
#        'Aberdeen - IT Spend Currency (in USD)'],
#       dtype='object')

# %%
categories_counts= data_BO['Categories'].value_counts().nlargest(30)
plt.figure(figsize=(5,7))
rg = sns.barplot(y=categories_counts.index, x=categories_counts.values)
plt.setp(rg.get_xticklabels(), rotation=90)
print(categories_counts)
# Out:
# Software                                                                      107
# Biotechnology                                                                  87
# Health Care                                                                    73
# E-Commerce                                                                     29
# Finance                                                                        26
# Internet                                                                       24
# Artificial Intelligence                                                        14
# Information Technology                                                         13
# Security                                                                       13
# Robotics                                                                       11
# Advertising                                                                    10
# Data                                                                           10
# Food                                                                            9
# Education                                                                       8
# Gaming                                                                          4
# Sports                                                                          4
# Insurance                                                                       4
# Real Estate                                                                     2
# 3D Printing, Consumer Electronics, Hardware                                     1
# Electronic Health Record (EHR), mHealth, Personal Health                        1
# Hospitality, Marketplace, Restaurants                                           1
# Developer APIs, Ediscovery, Music, Personalization, Search Engine               1
# Customer Service, Social Media                                                  1
# Analytics, Energy Efficiency, Energy Management, SaaS                           1
# Consumer Electronics, Energy Efficiency, Lighting                               1
# Computer Vision, Machine Learning, Physical Security, Public Safety             1
# Consumer Electronics, Fitness, Pet, Wearables                                   1
# Cloud Computing, Cloud Management, Developer Tools, Machine Learning, SaaS      1
# Automotive, Autonomous Vehicles                                                 1
# Analytics, Video, Video Streaming                                               1
# Name: Categories, dtype: int64

# %%
categories_counts= new_df['Number of Funding Rounds'].value_counts().nlargest(30)
plt.figure(figsize=(5,7))
rg = sns.barplot(y=categories_counts.index, x=categories_counts.values)
plt.setp(rg.get_xticklabels(), rotation=90)
print(categories_counts)
# Out:
# 2.0     2677
# 3.0     2378
# 1.0     2004
# 4.0     1709
# 5.0     1149
# 6.0      705
# 7.0      409
# 8.0      217
# 9.0      130
# 10.0      78
# 11.0      39
# 12.0      33
# 13.0      19
# 14.0      10
# 15.0       9
# 16.0       4
# 17.0       3
# 24.0       2
# 20.0       1
# 41.0       1
# 23.0       1
# 19.0       1
# 22.0       1
# 18.0       1
# 31.0       1
# Name: Number of Funding Rounds, dtype: int64

# %%
categories_counts= new_df['Number of Employees'].value_counts().nlargest(30)
plt.figure(figsize=(5,7))
rg = sns.barplot(y=categories_counts.index, x=categories_counts.values)
plt.setp(rg.get_xticklabels(), rotation=90)
print(categories_counts)
# Out:
# 11-50         4816
# 1-10          1853
# 51-100        1626
# 101-250       1309
# 251-500        572
# 501-1000       395
# 1001-5000      263
# 10001+          82
# 5001-10000      62
# Name: Number of Employees, dtype: int64

# %%
categories_counts= new_df['Funding Status'].value_counts().nlargest(30)
plt.figure(figsize=(5,7))
rg = sns.barplot(y=categories_counts.index, x=categories_counts.values)
plt.setp(rg.get_xticklabels(), rotation=90)
print(categories_counts)
# Out:
# Early Stage Venture    3404
# Seed                   2671
# M&A                    1368
# Late Stage Venture     1253
# IPO                     416
# Private Equity          210
# Name: Funding Status, dtype: int64

# %%
categories_counts= new_df['Estimated Revenue Range'].value_counts().nlargest(30)
plt.figure(figsize=(5,7))
rg = sns.barplot(y=categories_counts.index, x=categories_counts.values)
plt.setp(rg.get_xticklabels(), rotation=90)
print(categories_counts)
# Out:
# $1M to $10M       3656
# Less than $1M      832
# $10M to $50M       563
# $50M to $100M      121
# $100M to $500M      86
# $1B to $10B          9
# $500M to $1B         8
# $10B+                1
# Name: Estimated Revenue Range, dtype: int64

# %%
#What other attributes could be useful?
print (new_df.notnull().sum())
# Out:
# Organization Name                        11644
# Organization Name URL                    11644
# Categories                               11644
# Headquarters Location                    11644
# Description                              11644
# CB Rank (Company)                        11644
# Headquarters Regions                     11644
# Estimated Revenue Range                   5276
# Operating Status                         11644
# Founded Date                             11454
# Founded Date Precision                   11454
# Exit Date                                 1784
# Exit Date Precision                       1784
# Closed Date                                 24
# Closed Date Precision                       41
# Company Type                             10345
# Investor Type                               71
# Investment Stage                            61
# Category Groups                          11627
# Number of Founders                       11618
# Founders                                 11618
# Number of Employees                      10978
# Number of Funding Rounds                 11582
# Funding Status                            9322
# Last Funding Date                        11582
# Last Funding Amount                      10284
# Last Funding Amount Currency             10284
# Last Funding Amount Currency (in USD)    10284
# Last Funding Type                        11582
# Total Funding Amount                     11560
#                                          ...
# Aberdeen - IT Spend Currency              2578
# Aberdeen - IT Spend Currency (in USD)     2445
# Unnamed: 0                               11644
# Full Name                                11644
# Full Name URL                            11644
# Primary Job Title                        11644
# Primary Organization                     11644
# Primary Organization URL                 11644
# Location                                 10086
# CB Rank (Person)                         11644
# First Name                               11644
# Last Name                                11644
# Regions                                   9877
# Gender                                   11644
# Biography                                 8945
# Twitter                                   5607
# LinkedIn                                 10176
# Facebook                                  2935
# Number of News Articles                   7020
# Number of Founded Organizations          11603
# Number of Portfolio Companies             1480
# Number of Investments                     1480
# Number of Partner Investments              223
# Number of Lead Investments                 157
# Number of Exits                            454
# Number of Exits (IPO)                      454
# Number of Events_y                        3501
# Trend Score (7 Days)                     11644
# Trend Score (30 Days)                    11644
# Trend Score (90 Days)                    11644
# Length: 88, dtype: int64

# %%
data_numeric = data._get_numeric_data()
data_numeric
data_numeric.to_csv('data_numeric.csv')

# %%
tmp = data_numeric['Total Funding Amount Currency (in USD)']
data_numeric.drop(labels='Total Funding Amount Currency (in USD)',axis=1,inplace=True)
data_numeric.insert(0,'Total Funding Amount Currency (in USD)',tmp)
data_numeric
# Out:
#        Total Funding Amount Currency (in USD)  Number of Founders  \
# 0                                6.180000e+07                 4.0
# 1                                5.750000e+07                 2.0
# 2                                1.220000e+08                 1.0
# 3                                3.447000e+09                 8.0
# 4                                2.471245e+10                 3.0
# 5                                1.580000e+09                 2.0
# 6                                7.677000e+07                 3.0
# 7                                1.000000e+09                 1.0
# 8                                2.200000e+10                 1.0
# 9                                3.875000e+08                 2.0
# 10                               8.907000e+09                18.0
# 11                               1.401250e+09                 1.0
# 12                               3.789023e+09                 2.0
# 13                               8.700000e+09                 NaN
# 14                               4.025000e+09                 3.0
# 15                               6.025000e+07                 2.0
# 16                               5.268800e+09                 3.0
# 17                               2.436000e+08                 NaN
# 18                               3.103736e+09                 2.0
# 19                               1.000000e+09                 2.0
# 20                               3.500000e+08                 3.0
# 21                               1.702526e+08                 NaN
# 22                               5.905000e+08                 2.0
# 23                               3.131000e+08                 2.0
# 24                               5.053130e+05                 NaN
# 25                               3.711000e+08                 7.0
# 26                               6.500000e+06                 1.0
# 27                               3.400000e+08                 1.0
# 28                               4.300000e+09                 1.0
# 29                               3.752000e+08                 2.0
# ...                                       ...                 ...
# 29970                            3.200000e+05                 2.0
# 29971                            1.054915e+07                 1.0
# 29972                            2.500000e+06                 2.0
# 29973                            2.759500e+07                 1.0
# 29974                                     NaN                 1.0
# 29975                            7.650390e+05                 3.0
# 29976                            2.235932e+06                 2.0
# 29977                                     NaN                 NaN
# 29978                            6.950000e+06                 1.0
# 29979                            2.080000e+07                 2.0
# 29980                            2.293258e+06                 2.0
# 29981                            2.513289e+06                 3.0
# 29982                            7.000000e+05                 2.0
# 29983                            2.000000e+07                 4.0
# 29984                            2.550000e+07                 3.0
# 29985                            1.270000e+06                 4.0
# 29986                            6.000000e+07                 1.0
# 29987                            3.668370e+07                 NaN
# 29988                            6.200000e+06                 2.0
# 29989                            1.573111e+06                 1.0
# 29990                            3.598326e+06                 2.0
# 29991                            2.630000e+07                 2.0
# 29992                            3.100000e+06                 4.0
# 29993                            1.101100e+08                 1.0
# 29994                            2.000000e+06                 1.0
# 29995                            4.450000e+07                 NaN
# 29996                            2.470000e+08                 NaN
# 29997                            1.350000e+06                 2.0
# 29998                            8.994150e+05                 1.0
# 29999                            3.574045e+07                 1.0
#
#        Number of Funding Rounds  Last Funding Amount  \
# 0                           4.0         2.780000e+07
# 1                           4.0         5.000000e+07
# 2                           7.0         5.000000e+07
# 3                           9.0         1.000000e+09
# 4                          23.0         5.000000e+08
# 5                           2.0         1.250000e+09
# 6                           4.0         4.435000e+07
# 7                           1.0         1.000000e+09
# 8                           4.0         1.400000e+10
# 9                           8.0                  NaN
# 10                         16.0         1.000000e+09
# 11                          5.0         5.000000e+08
# 12                         22.0         3.000000e+08
# 13                          2.0         1.200000e+09
# 14                          4.0         4.000000e+09
# 15                          3.0         5.200000e+07
# 16                          7.0         1.150000e+09
# 17                          2.0         2.016000e+08
# 18                         10.0         1.900000e+09
# 19                          1.0         1.000000e+09
# 20                          2.0         2.500000e+08
# 21                          1.0         1.500000e+08
# 22                          8.0                  NaN
# 23                          9.0         1.030000e+08
# 24                          2.0         1.509220e+05
# 25                          5.0         2.000000e+08
# 26                          1.0         6.500000e+06
# 27                          6.0         1.100000e+08
# 28                          3.0         1.300000e+09
# 29                          7.0         1.126000e+08
# ...                         ...                  ...
# 29970                       3.0         1.500000e+05
# 29971                       1.0         1.054915e+07
# 29972                       1.0         2.500000e+06
# 29973                       3.0         6.000000e+06
# 29974                       NaN                  NaN
# 29975                       2.0         7.000000e+05
# 29976                       3.0         7.000000e+06
# 29977                       NaN                  NaN
# 29978                       2.0         5.000000e+06
# 29979                       1.0         2.080000e+07
# 29980                       2.0         2.023258e+06
# 29981                       4.0         6.250000e+05
# 29982                       7.0                  NaN
# 29983                       1.0         2.000000e+07
# 29984                       3.0         8.500000e+06
# 29985                       2.0         1.500000e+05
# 29986                       1.0         6.000000e+07
# 29987                       5.0         2.100000e+07
# 29988                       4.0         4.000000e+06
# 29989                       1.0         2.200000e+07
# 29990                       3.0         2.000000e+06
# 29991                       4.0         1.550000e+07
# 29992                       2.0                  NaN
# 29993                       5.0         5.110000e+06
# 29994                       1.0         2.000000e+06
# 29995                       2.0         4.800000e+06
# 29996                       1.0         2.470000e+08
# 29997                       3.0         1.000000e+06
# 29998                       2.0         7.000000e+05
# 29999                       7.0         1.200000e+07
#
#        Last Funding Amount Currency (in USD)  Total Funding Amount  \
# 0                               2.780000e+07          6.180000e+07
# 1                               5.000000e+07          5.750000e+07
# 2                               5.000000e+07          1.220000e+08
# 3                               1.000000e+09          3.447000e+09
# 4                               5.000000e+08          2.471245e+10
# 5                               1.250000e+09          1.580000e+09
# 6                               4.435000e+07          7.677000e+07
# 7                               1.000000e+09          1.000000e+09
# 8                               1.400000e+10          2.200000e+10
# 9                                        NaN          3.875000e+08
# 10                              1.000000e+09          8.907000e+09
# 11                              5.000000e+08          1.401250e+09
# 12                              3.000000e+08          3.789023e+09
# 13                              1.200000e+09          8.700000e+09
# 14                              4.000000e+09          4.025000e+09
# 15                              5.200000e+07          6.025000e+07
# 16                              1.150000e+09          5.268800e+09
# 17                              2.016000e+08          2.436000e+08
# 18                              1.900000e+09          3.103736e+09
# 19                              1.000000e+09          1.000000e+09
# 20                              2.500000e+08          3.500000e+08
# 21                              1.702526e+08          1.500000e+08
# 29997                  NaN                                    NaN
# 29998                  NaN                                    NaN
# 29999                  NaN                                    NaN
#
#        Valuation at IPO  Valuation at IPO Currency (in USD)  Number of Events  \
# 0                   NaN                                 NaN             310.0
# 1                   NaN                                 NaN               7.0
# 2          1.457000e+09                        1.457000e+09               NaN
# 3          5.270000e+10                        5.270000e+10               4.0
# 4          8.240000e+10                        8.240000e+10              57.0
# 5                   NaN                                 NaN               9.0
# 6          1.100000e+10                        1.100000e+10              17.0
# 7                   NaN                                 NaN               4.0
# 8                   NaN                                 NaN               8.0
# 9                   NaN                                 NaN               NaN
# 10                  NaN                                 NaN              19.0
# 11                  NaN                                 NaN               NaN
# 12                  NaN                                 NaN               NaN
# 13                  NaN                                 NaN              32.0
# 14                  NaN                                 NaN             101.0
# 15                  NaN                                 NaN               NaN
# 16                  NaN                                 NaN               4.0
# 17                  NaN                                 NaN              12.0
# 18         3.097211e+08                        3.097211e+08              24.0
# 19                  NaN                                 NaN               2.0
# 20                  NaN                                 NaN              92.0
# 21                  NaN                                 NaN              13.0
# 22         2.900000e+09                        2.900000e+09              15.0
# 23                  NaN                                 NaN               5.0
# 24                  NaN                                 NaN               6.0
# 25                  NaN                                 NaN              40.0
# 26                  NaN                                 NaN              12.0
# 27                  NaN                                 NaN              54.0
# 28                  NaN                                 NaN               3.0
# 29                  NaN                                 NaN               1.0
# ...                 ...                                 ...               ...
# 29970               NaN                                 NaN               NaN
# 29971               NaN                                 NaN               NaN
# 29972               NaN                                 NaN               NaN
# 29973               NaN                                 NaN               1.0
# 29974               NaN                                 NaN               NaN
# 29975               NaN                                 NaN               2.0
# 29976               NaN                                 NaN               NaN
# 29977               NaN                                 NaN               3.0
# 29978               NaN                                 NaN               NaN
# 29979               NaN                                 NaN               NaN
# 29980               NaN                                 NaN               NaN
# 29981               NaN                                 NaN               NaN
# 29982               NaN                                 NaN               1.0
# 29983               NaN                                 NaN               4.0
# 29984               NaN                                 NaN               NaN
# 29985               NaN                                 NaN               NaN
# 29986               NaN                                 NaN               NaN
# 29987               NaN                                 NaN               NaN
# 29988               NaN                                 NaN               NaN
# 29989               NaN                                 NaN               NaN
# 29990               NaN                                 NaN               1.0
# 29991               NaN                                 NaN               NaN
# 29992               NaN                                 NaN               2.0
# 29993               NaN                                 NaN               NaN
# 29994               NaN                                 NaN               NaN
# 29995               NaN                                 NaN               1.0
# 29996               NaN                                 NaN               NaN
# 29997               NaN                                 NaN               2.0
# 29998               NaN                                 NaN               NaN
# 29999               NaN                                 NaN               NaN
#
#        BuiltWith - Active Tech Count  Siftery - Total Products Active  \
# 0                               45.0                            141.0
# 1                               36.0                             46.0
# 2                               49.0                             21.0
# 3                               61.0                             14.0
# 4                               65.0                            208.0
# 5                               26.0                             37.0
# 6                                3.0                             20.0
# 7                               16.0                              5.0
# 8                               12.0                              3.0
# 9                               40.0                             13.0
# 10                              10.0                             15.0
# 11                              43.0                             10.0
# 12                              54.0                             49.0
# 13                              67.0                            104.0
# 14                             134.0                             99.0
# 15                              19.0                             19.0
# 16                              38.0                             28.0
# 17                              26.0                             24.0
# 18                              85.0                            122.0
# 19                               9.0                             75.0
# 20                               8.0                             82.0
# 21                             102.0                             50.0
# 22                              28.0                            125.0
# 23                              84.0                             86.0
# 24                              75.0                            117.0
# 25                             127.0                              NaN
# 26                              90.0                            149.0
# 27                              62.0                             87.0
# 28                              26.0                              5.0
# 29                              83.0                             40.0
# ...                              ...                              ...
# 29970                           46.0                              NaN
# 29971                           16.0                             17.0
# 29972                           10.0                              7.0
# 29973                           26.0                              5.0
# 29974                           65.0                             53.0
# 29975                           14.0                             11.0
# 29976                           58.0                             18.0
# 29977                           85.0                              NaN
# 29978                           75.0                             13.0
# 29979                           39.0                              NaN
# 29980                           66.0                             22.0
# 29981                           57.0                             21.0
# 29982                           59.0                             66.0
# 29983                          103.0                            118.0
# 29984                            8.0                              4.0
# 29985                            7.0                             13.0
# 29986                            5.0                              NaN
# 29987                           10.0                              1.0
# 29988                           25.0                             13.0
# 29989                           15.0                              NaN
# 29990                           30.0                             16.0
# 29991                           16.0                              7.0
# 29992                           31.0                              9.0
# 29993                            9.0                              6.0
# 29994                            8.0                             15.0
# 29995                           63.0                              6.0
# 29996                           32.0                              NaN
# 29997                           58.0                             29.0
# 29998                           38.0                             13.0
# 29999                           27.0                              7.0
#
#        Aberdeen - IT Spend  Aberdeen - IT Spend Currency (in USD)
# 0             1.691130e+05                           1.691130e+05
# 1                      NaN                                    NaN
# 2             2.659270e+05                           2.659270e+05
# 3                      NaN                                    NaN
# 4                      NaN                                    NaN
# 5             4.977418e+06                           4.977418e+06
# 6                      NaN                                    NaN
# 7                      NaN                                    NaN
# 8                      NaN                                    NaN
# 9             5.005280e+05                           5.005280e+05
# 10                     NaN                                    NaN
# 11            7.948900e+05                           7.948900e+05
# 12                     NaN                                    NaN
# 13            7.246647e+09                           7.246647e+09
# 14                     NaN                                    NaN
# 15                     NaN                                    NaN
# 16                     NaN                                    NaN
# 17                     NaN                                    NaN
# 18                     NaN                                    NaN
# 19                     NaN                                    NaN
# 20                     NaN                                    NaN
# 21                     NaN                                    NaN
# 22                     NaN                                    NaN
# 23            1.236665e+06                           1.236665e+06
# 24                     NaN                                    NaN
# 25                     NaN                                    NaN
# 26                     NaN                                    NaN
# 27            7.706910e+05                           7.706910e+05
# 28                     NaN                                    NaN
# 29            6.938540e+05                           6.938540e+05
# ...                    ...                                    ...
# 29970                  NaN                                    NaN
# 29971                  NaN                                    NaN
# 29972                  NaN                                    NaN
# 29973         3.857900e+04                           3.857900e+04
# 29974                  NaN                                    NaN
# 29975                  NaN                                    NaN
# 29976                  NaN                                    NaN
# 29977                  NaN                                    NaN
# 29978                  NaN                                    NaN
# 29979         2.290735e+06                           2.290735e+06
# 29980         9.086800e+04                           9.086800e+04
# 29981                  NaN                                    NaN
# 29982                  NaN                                    NaN
# 29983                  NaN                                    NaN
# 29984                  NaN                                    NaN
# 29985                  NaN                                    NaN
# 29986                  NaN                                    NaN
# 29987         1.589850e+05                           1.589850e+05
# 29988                  NaN                                    NaN
# 29989                  NaN                                    NaN
# 29990                  NaN                                    NaN
# 29991         8.522100e+04                           8.522100e+04
# 29992                  NaN                                    NaN
# 29993                  NaN                                    NaN
# 29994                  NaN                                    NaN
# 29995                  NaN                                    NaN
# 29996                  NaN                                    NaN
# 29997                  NaN                                    NaN
# 29998                  NaN                                    NaN
# 29999                  NaN                                    NaN
#
# [30000 rows x 18 columns]

# %%
name_array = data_numeric.columns
name_array
# Out:
# Index(['Total Funding Amount Currency (in USD)', 'Number of Founders',
#        'Number of Funding Rounds', 'Last Funding Amount',
#        'Last Funding Amount Currency (in USD)', 'Total Funding Amount',
#        'Number of Lead Investors', 'Number of Investors',
#        'Number of Acquisitions', 'Money Raised at IPO',
#        'Money Raised at IPO Currency (in USD)', 'Valuation at IPO',
#        'Valuation at IPO Currency (in USD)', 'Number of Events',
#        'BuiltWith - Active Tech Count', 'Siftery - Total Products Active',
#        'Aberdeen - IT Spend', 'Aberdeen - IT Spend Currency (in USD)'],
#       dtype='object')

# %%
pos = 1 # use as position tracker for subplots function
#array1 = ["fixed acidity","volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcohol","quality"]
plt.subplots(6,3, figsize=(35,30)) # subplot function with 4 rows 3 columns and 15x13 in dimension for each graph
for item in name_array: # forloop to plot each graph one by one
    plt.subplot(6,3,pos) # plot each graph in all 12 slots
    plt.hist(data_numeric[item],rwidth = 0.9, bins = 20) # plot the histograph with each row in white_wine with 0.9 width between bars
    plt.xlabel(item) # x label as the name of the column
    plt.ylabel('Frequency')
    plt.title(item) # title is the same as x label
    pos = pos + 1 # increment pos for next graph
plt.tight_layout() # tighten the layout to avoid overlap among the titles and labels
# Out:
# /Users/benjamin/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/benjamin/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
name_array = data_numeric.columns
name_array
# Out:
# Index(['Total Funding Amount Currency (in USD)', 'Number of Founders',
#        'Number of Funding Rounds', 'Last Funding Amount',
#        'Last Funding Amount Currency (in USD)', 'Total Funding Amount',
#        'Number of Lead Investors', 'Number of Investors',
#        'Number of Acquisitions', 'Money Raised at IPO',
#        'Money Raised at IPO Currency (in USD)', 'Valuation at IPO',
#        'Valuation at IPO Currency (in USD)', 'Number of Events',
#        'BuiltWith - Active Tech Count', 'Siftery - Total Products Active',
#        'Aberdeen - IT Spend', 'Aberdeen - IT Spend Currency (in USD)'],
#       dtype='object')

# %%
cor = data_numeric.corr() # create a 12x12 matrix named cor filled with correlation between each pair of columns
plt.figure(figsize=(18,10)) # set the dimension of the heatmap to 18x5
print (sns.heatmap(cor,annot=True,cmap="Blues"))
# Out:
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
look at paper with crunchbase data
if not much then we can post a subartcle or a medium
# Out:
#   File "<ipython-input-27-ed36ff1c4b6b>", line 1
#     look at paper with crunchbase data
#           ^
# SyntaxError: invalid syntax
