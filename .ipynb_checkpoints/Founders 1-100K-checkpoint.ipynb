# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
founders = pd.read_csv('founders_1-100k.csv')
founders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36166 entries, 0 to 36165
# Data columns (total 28 columns):
# Unnamed: 0                         36166 non-null int64
# Full Name                          36166 non-null object
# Full Name URL                      36166 non-null object
# Primary Job Title                  36166 non-null object
# Primary Organization               36166 non-null object
# Primary Organization URL           36166 non-null object
# Location                           29878 non-null object
# CB Rank (Person)                   36166 non-null object
# First Name                         36166 non-null object
# Last Name                          36166 non-null object
# Regions                            27519 non-null object
# Gender                             36080 non-null object
# Biography                          26659 non-null object
# Twitter                            15787 non-null object
# LinkedIn                           29964 non-null object
# Facebook                           8361 non-null object
# Number of News Articles            18279 non-null object
# Number of Founded Organizations    35907 non-null float64
# Number of Portfolio Companies      4357 non-null float64
# Number of Investments              4357 non-null float64
# Number of Partner Investments      1655 non-null float64
# Number of Lead Investments         490 non-null float64
# Number of Exits                    1251 non-null float64
# Number of Exits (IPO)              1251 non-null float64
# Number of Events                   8475 non-null float64
# Trend Score (7 Days)               36166 non-null float64
# Trend Score (30 Days)              36166 non-null float64
# Trend Score (90 Days)              36166 non-null float64
# dtypes: float64(11), int64(1), object(16)
# memory usage: 7.7+ MB
# /home/bossou/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
fds = founders.drop(['Unnamed: 0', 'Full Name URL', 'Primary Organization URL', 
                 'Trend Score (7 Days)', 'Trend Score (30 Days)', 'Trend Score (90 Days)',
                     'Facebook', 'LinkedIn', 'Twitter', 'First Name', 'Last Name'], axis=1)
fds.head()
# Out:
#          Full Name   Primary Job Title        Primary Organization  \
# 0  Jason Calacanis       Founder & CEO                  Inside.com
# 1     LeBron James          Co-Founder                  PureBrands
# 2     Marc Benioff    Founder & Co-CEO                  Salesforce
# 3  Serena Williams             Founder  Serena Williams Foundation
# 4       Jeff Kearl  Co-Founder and CEO                      Stance
#
#                                      Location CB Rank (Person)  \
# 0    San Francisco, California, United States                2
# 1              Cleveland, Ohio, United States                4
# 2    San Francisco, California, United States                7
# 3  Palm Beach Gardens, Florida, United States                8
# 4     San Clemente, California, United States               13
#
#                                             Regions  Gender  \
# 0    San Francisco Bay Area, West Coast, Western US    Male
# 1                        Great Lakes, Midwestern US    Male
# 2    San Francisco Bay Area, West Coast, Western US    Male
# 3       Greater Miami Area, East Coast, Southern US  Female
# 4  Greater Los Angeles Area, West Coast, Western US    Male
#
#                                            Biography Number of News Articles  \
# 0  Jason McCabe Calacanis hosts "This Week In Sta...                   1,090
# 1  LeBron James is an international basketball st...                   7,573
# 2  Marc Benioff is Chairman, co-Chief Executive O...                   4,465
# 3  Serena Williams is an American professional te...                   2,666
# 4  Jeff Kearl serves as the Chief Executive Offic...                      21
#
#    Number of Founded Organizations  Number of Portfolio Companies  \
# 0                              6.0                           61.0
# 1                              1.0                            2.0
# 2                              1.0                           92.0
# 3                              1.0                            1.0
# 4                              1.0                           24.0
#
#    Number of Investments  Number of Partner Investments  \
# 0                   70.0                          122.0
# 1                    3.0                            NaN
# 2                  125.0                            NaN
# 3                    1.0                           22.0
# 4                   27.0                            4.0
#
#    Number of Lead Investments  Number of Exits  Number of Exits (IPO)  \
# 0                         5.0             18.0                   18.0
# 1                         NaN              1.0                    1.0
# 2                         8.0             24.0                   24.0
# 3                         NaN              NaN                    NaN
# 4                         NaN             10.0                   10.0
#
#    Number of Events
# 0               8.0
# 1               NaN
# 2              20.0
# 3               1.0
# 4               1.0

# %%
fds['Number of News Articles'] = fds['Number of News Articles'].str.replace(',', '').astype(float)
fds['CB Rank (Person)'] = fds['CB Rank (Person)'].str.replace(',', '').astype(int)

# %%
fds.isna().sum()
# Out:
# Full Name                              0
# Primary Job Title                      0
# Primary Organization                   0
# Location                            6288
# CB Rank (Person)                       0
# Regions                             8647
# Gender                                86
# Biography                           9507
# Number of News Articles            19016
# Number of Founded Organizations      259
# Number of Portfolio Companies      31809
# Number of Investments              31809
# Number of Partner Investments      34511
# Number of Lead Investments         35676
# Number of Exits                    34915
# Number of Exits (IPO)              34915
# Number of Events                   27691
# dtype: int64

# %%
job_title_counts = fds['Primary Job Title'].value_counts().nlargest(30)
plt.figure(figsize=(10,12))
rg = sns.barplot(y=job_title_counts.index, x=job_title_counts.values)
plt.setp(rg.get_xticklabels(), rotation=90)
plt.show()

# %%
fds['Regions'].value_counts(normalize=True)
# Out:
# San Francisco Bay Area, West Coast, Western US                                         0.190378
# European Union (EU)                                                                    0.168792
# Greater New York Area, East Coast, Northeastern US                                     0.121916
# Asia-Pacific (APAC)                                                                    0.092082
# Greater Los Angeles Area, West Coast, Western US                                       0.059741
# San Francisco Bay Area, Silicon Valley, West Coast                                     0.044006
# Greater Boston Area, East Coast, New England                                           0.038264
# Asia-Pacific (APAC), Association of Southeast Asian Nations (ASEAN), Southeast Asia    0.028453
# West Coast, Western US                                                                 0.027508
# Great Lakes                                                                            0.019550
# Southern US                                                                            0.018860
# Greater Seattle Area, West Coast, Western US                                           0.015989
# Greater Chicago Area, Great Lakes, Midwestern US                                       0.015916
# Asia-Pacific (APAC), Australasia                                                       0.013482
# European Union (EU), Nordic Countries, Scandinavia                                     0.011556
# Washington DC Metro Area, Southern US                                                  0.011011
# Western US                                                                             0.010865
# Greater San Diego Area, West Coast, Western US                                         0.009593
# Great Lakes, Midwestern US                                                             0.009557
# Greater Denver Area, Western US                                                        0.009303
# East Coast, Southern US                                                                0.008285
# Greater Miami Area, East Coast, Southern US                                            0.007340
# Greater Atlanta Area, East Coast, Southern US                                          0.006287
# Greater Philadelphia Area, Great Lakes, Northeastern US                                0.005996
# Dallas/Fort Worth Metroplex, Southern US                                               0.005741
# Gulf Cooperation Council (GCC)                                                         0.005414
# East Coast                                                                             0.004724
# Midwestern US                                                                          0.004034
# Greater Phoenix Area, Western US                                                       0.003598
# Washington DC Metro Area, East Coast, Southern US                                      0.003598
# East Coast, New England, Northeastern US                                               0.003307
# Greater Houston Area, Southern US                                                      0.003234
# Great Lakes, Northeastern US                                                           0.002943
# Research Triangle, East Coast, Southern US                                             0.002871
# Greater Baltimore-Maryland Area, East Coast, Southern US                               0.002253
# East Coast, Northeastern US                                                            0.002217
# Greater Minneapolis-Saint Paul Area, Great Lakes, Midwestern US                        0.002217
# East Coast, New England                                                                0.001926
# Nordic Countries, Scandinavia                                                          0.001926
# Greater Detroit Area, Great Lakes, Midwestern US                                       0.001853
# Tampa Bay Area, East Coast, Southern US                                                0.001236
# Great Lakes, East Coast, Northeastern US                                               0.000581
# Asia-Pacific (APAC), Western US                                                        0.000509
# Greater New York Area, European Union (EU)                                             0.000327
# New England, Northeastern US                                                           0.000291
# Greater Los Angeles Area, Inland Empire, West Coast                                    0.000254
# Greater Philadelphia Area, East Coast, Southern US                                     0.000182
# Greater Philadelphia Area, East Coast, Northeastern US                                 0.000036
# Name: Regions, dtype: float64

# %%
plt.figure(figsize=(16,7))
rg = sns.countplot(x="Regions", data=fds)
plt.setp(rg.get_xticklabels(), rotation=90)
plt.show()

# %%
sns.countplot(x="Number of Exits", data=fds)
plt.show()

# %%
fds['Gender'].value_counts(dropna=False)
# Out:
# Male                      32027
# Female                     4041
# NaN                          86
# Prefer not to identify        9
# Genderqueer                   1
# Transgender Woman             1
# Bigender                      1
# Name: Gender, dtype: int64

# %%
fds['Gender'].value_counts(normalize=True, dropna=False)
# Out:
# Male                      0.885555
# Female                    0.111735
# NaN                       0.002378
# Prefer not to identify    0.000249
# Genderqueer               0.000028
# Transgender Woman         0.000028
# Bigender                  0.000028
# Name: Gender, dtype: float64

# %%
ax = sns.countplot(x='Gender', data=fds)

# %%
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Number of Exits (IPO)', hue='Gender', data=fds)
plt.legend(loc='upper right')
plt.show()

# %%
fds['Number of Exits'].groupby(fds['Gender']).value_counts(dropna=False)
# Out:
# Gender                  Number of Exits
# Bigender                NaN                    1
# Female                  NaN                 3981
#                         1.0                   43
#                         2.0                    6
#                         3.0                    6
#                         4.0                    3
#                         5.0                    1
#                         22.0                   1
# Genderqueer             NaN                    1
# Male                    NaN                30837
#                         1.0                  787
#                         2.0                  186
#                         3.0                   60
#                         4.0                   43
#                         6.0                   25
#                         5.0                   23
#                         7.0                   13
#                         8.0                    8
#                         10.0                   7
#                         9.0                    4
#                         13.0                   4
#                         0.0                    3
#                         12.0                   3
#                         16.0                   3
#                         17.0                   3
#                         11.0                   2
#                         14.0                   2
#                         18.0                   2
#                         20.0                   2
#                         24.0                   2
#                         15.0                   1
#                         19.0                   1
#                         22.0                   1
#                         27.0                   1
#                         39.0                   1
#                         40.0                   1
#                         50.0                   1
#                         57.0                   1
# Prefer not to identify  NaN                    9
# Transgender Woman       NaN                    1
# Name: Number of Exits, dtype: int64

# %%
fds['Number of Exits'].groupby(fds['Gender']).value_counts(normalize=True)
# Out:
# Gender  Number of Exits
# Female  1.0                0.716667
#         2.0                0.100000
#         3.0                0.100000
#         4.0                0.050000
#         5.0                0.016667
#         22.0               0.016667
# Male    1.0                0.661345
#         2.0                0.156303
#         3.0                0.050420
#         4.0                0.036134
#         6.0                0.021008
#         5.0                0.019328
#         7.0                0.010924
#         8.0                0.006723
#         10.0               0.005882
#         9.0                0.003361
#         13.0               0.003361
#         0.0                0.002521
#         12.0               0.002521
#         16.0               0.002521
#         17.0               0.002521
#         11.0               0.001681
#         14.0               0.001681
#         18.0               0.001681
#         20.0               0.001681
#         24.0               0.001681
#         15.0               0.000840
#         19.0               0.000840
#         22.0               0.000840
#         27.0               0.000840
#         39.0               0.000840
#         40.0               0.000840
#         50.0               0.000840
#         57.0               0.000840
# Name: Number of Exits, dtype: float64

# %%
plt.figure(figsize=(10,6))
ax = sns.scatterplot(x='CB Rank (Person)', y='Number of Exits (IPO)', hue='Gender', data=fds)
plt.legend(loc='upper right')
plt.show()

# %%
fds.describe()
# Out:
#        CB Rank (Person)  Number of News Articles  \
# count      36166.000000             17150.000000
# mean       45508.965769                34.609329
# std        28278.734220               460.155180
# min            2.000000                 0.000000
# 25%        20627.250000                 2.000000
# 50%        43590.000000                 5.000000
# 75%        69719.250000                14.000000
# max        97997.000000             45526.000000
#
#        Number of Founded Organizations  Number of Portfolio Companies  \
# count                     35907.000000                    4357.000000
# mean                          1.422926                       3.168465
# std                           0.886964                       6.830332
# min                           1.000000                       0.000000
# 25%                           1.000000                       1.000000
# 50%                           1.000000                       1.000000
# 75%                           2.000000                       3.000000
# max                          20.000000                     207.000000
#
#        Number of Investments  Number of Partner Investments  \
# count            4357.000000                    1655.000000
# mean                3.474179                       9.018127
# std                 7.777206                      16.480714
# min                 0.000000                       1.000000
# 25%                 1.000000                       1.000000
# 50%                 1.000000                       3.000000
# 75%                 3.000000                      10.000000
# max               242.000000                     238.000000
#
#        Number of Lead Investments  Number of Exits  Number of Exits (IPO)  \
# count                  490.000000      1251.000000            1251.000000
# mean                     1.363265         2.223022               2.223022
# std                      0.954313         3.747295               3.747295
# min                      0.000000         0.000000               0.000000
# 25%                      1.000000         1.000000               1.000000
# 50%                      1.000000         1.000000               1.000000
# 75%                      1.000000         2.000000               2.000000
# max                      8.000000        57.000000              57.000000
#
#        Number of Events
# count       8475.000000
# mean           2.267021
# std            2.444395
# min            0.000000
# 25%            1.000000
# 50%            1.000000
# 75%            3.000000
# max           35.000000

# %% [markdown]
# # Mesure of Sucess Evaluation

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
data_numeric = fds.select_dtypes(include=numerics)
cor = data_numeric.corr()
plt.figure(figsize=(12,10))
sns.heatmap(cor,annot=True,cmap="Blues")
plt.show()

# %%
fds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36166 entries, 0 to 36165
# Data columns (total 17 columns):
# Full Name                          36166 non-null object
# Primary Job Title                  36166 non-null object
# Primary Organization               36166 non-null object
# Location                           29878 non-null object
# CB Rank (Person)                   36166 non-null int64
# Regions                            27519 non-null object
# Gender                             36080 non-null object
# Biography                          26659 non-null object
# Number of News Articles            17150 non-null float64
# Number of Founded Organizations    35907 non-null float64
# Number of Portfolio Companies      4357 non-null float64
# Number of Investments              4357 non-null float64
# Number of Partner Investments      1655 non-null float64
# Number of Lead Investments         490 non-null float64
# Number of Exits                    1251 non-null float64
# Number of Exits (IPO)              1251 non-null float64
# Number of Events                   8475 non-null float64
# dtypes: float64(9), int64(1), object(7)
# memory usage: 4.7+ MB

# %%
fds['Number of Founded Organizations'].value_counts(dropna=False, normalize=True)
# Out:
# 1.0     0.716363
# 2.0     0.189792
# 3.0     0.055301
# 4.0     0.019632
# NaN     0.007161
# 5.0     0.006498
# 6.0     0.002571
# 7.0     0.001106
# 8.0     0.000553
# 9.0     0.000304
# 10.0    0.000194
# 11.0    0.000111
# 12.0    0.000111
# 19.0    0.000083
# 13.0    0.000055
# 18.0    0.000028
# 14.0    0.000028
# 20.0    0.000028
# 16.0    0.000028
# 17.0    0.000028
# 15.0    0.000028
# Name: Number of Founded Organizations, dtype: float64

# %%
fds['Number of Exits (IPO)'].value_counts(dropna=False, normalize=True)
# Out:
# NaN     0.965410
# 1.0     0.022950
# 2.0     0.005337
# 3.0     0.001825
# 4.0     0.001272
# 6.0     0.000691
# 5.0     0.000664
# 7.0     0.000359
# 8.0     0.000221
# 10.0    0.000194
# 13.0    0.000111
# 9.0     0.000111
# 16.0    0.000083
# 0.0     0.000083
# 17.0    0.000083
# 12.0    0.000083
# 14.0    0.000055
# 18.0    0.000055
# 20.0    0.000055
# 22.0    0.000055
# 24.0    0.000055
# 11.0    0.000055
# 27.0    0.000028
# 50.0    0.000028
# 57.0    0.000028
# 40.0    0.000028
# 19.0    0.000028
# 39.0    0.000028
# 15.0    0.000028
# Name: Number of Exits (IPO), dtype: float64

# %%
fds['Number of Portfolio Companies'].value_counts(dropna=False, normalize=True)
# Out:
# NaN      0.879528
# 1.0      0.065669
# 2.0      0.020544
# 3.0      0.010922
# 4.0      0.005696
# 5.0      0.003622
# 6.0      0.002433
# 7.0      0.002074
# 8.0      0.001327
# 9.0      0.001106
# 10.0     0.001023
# 11.0     0.000747
# 12.0     0.000664
# 13.0     0.000525
# 14.0     0.000498
# 15.0     0.000359
# 16.0     0.000304
# 17.0     0.000277
# 19.0     0.000249
# 18.0     0.000221
# 21.0     0.000194
# 22.0     0.000166
# 27.0     0.000138
# 24.0     0.000138
# 25.0     0.000083
# 26.0     0.000083
# 20.0     0.000083
# 36.0     0.000055
# 39.0     0.000055
# 38.0     0.000055
# 30.0     0.000055
# 28.0     0.000055
# 66.0     0.000055
# 49.0     0.000055
# 33.0     0.000055
# 78.0     0.000055
# 23.0     0.000055
# 37.0     0.000055
# 55.0     0.000055
# 46.0     0.000055
# 40.0     0.000055
# 34.0     0.000055
# 35.0     0.000028
# 111.0    0.000028
# 52.0     0.000028
# 53.0     0.000028
# 32.0     0.000028
# 207.0    0.000028
# 0.0      0.000028
# 48.0     0.000028
# 84.0     0.000028
# 47.0     0.000028
# 61.0     0.000028
# 29.0     0.000028
# 51.0     0.000028
# 109.0    0.000028
# 92.0     0.000028
# 54.0     0.000028
# 41.0     0.000028
# 56.0     0.000028
# Name: Number of Portfolio Companies, dtype: float64

# %%
fds['Number of News Articles'].value_counts(dropna=False, normalize=True).nlargest(20)
# Out:
# NaN     0.525798
# 1.0     0.097025
# 2.0     0.055494
# 3.0     0.040535
# 4.0     0.032683
# 5.0     0.026572
# 6.0     0.020931
# 7.0     0.017586
# 8.0     0.015235
# 9.0     0.012664
# 10.0    0.011254
# 11.0    0.008074
# 13.0    0.007963
# 12.0    0.007714
# 15.0    0.005724
# 14.0    0.005696
# 16.0    0.005281
# 19.0    0.004673
# 17.0    0.004452
# 18.0    0.004313
# Name: Number of News Articles, dtype: float64

# %%
# average number of exits per gender
# gender percentage 

# mapof the world with_ regions features
# heatmap of the world
# wirte a medium article
# local cv stuff
# get ethnicity based on twitter and_ linkedin
# use geopy for_ mapping longititude and_ latitude
